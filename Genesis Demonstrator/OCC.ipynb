# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib 
import os
from glob import glob

root = "./data/"

# %% [markdown]
# ## 1. Load

# %%
data = {}
for file in os.listdir(root):
    data[file.split("_")[-1].split(".")[0]] = pd.read_csv(os.path.join(root, file))

# %%
data.keys()
# Out:
# dict_keys(['AnomalyLabels', 'lineardrive', 'normal', 'pressure', 'StateMachineLabel'])

# %%
plt.figure(figsize=(20, 5))
plt.plot(data["AnomalyLabels"][data["AnomalyLabels"]["Label"]==0]["MotorData.IsForce"])
for idx in range(1, len(data["AnomalyLabels"][data["AnomalyLabels"]["Label"]==0]["Timestamp"])//550+1):
    plt.axvline(x=550*idx, color="r", linestyle="--")
plt.show()
