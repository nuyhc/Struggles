# %% [markdown]
# # Iris
# ## EDA & Preprocessing
# ### 사용 라이브러리

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import koreanize_matplotlib
from sklearn.datasets import load_iris

# %% [markdown]
# ### Data Load

# %%
iris = load_iris()

# %%
iris_data = iris.data # feature만으로 된 데이터
iris_label = iris.target # label 데이터
print(f"iris target: {iris.target_names}")
# Out:
# iris target: ['setosa' 'versicolor' 'virginica']

# %%
df_iris = pd.DataFrame(data=iris_data, columns=iris.feature_names)
df_iris["label"] = iris.target
df_iris.sample(5)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 96                 5.7               2.9                4.2               1.3
# 130                7.4               2.8                6.1               1.9
# 29                 4.7               3.2                1.6               0.2
# 89                 5.5               2.5                4.0               1.3
# 74                 6.4               2.9                4.3               1.3
#
#      label
# 96       1
# 130      2
# 29       0
# 89       1
# 74       1

# %% [markdown]
# - sepal: 꽃 받침
# - petal: 꽃잎
# - label
#   - 0: Setosa
#   - 1: versicolor
#   - 2: virginica

# %% [markdown]
# ### EDA

# %%
df_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   label              150 non-null    int32
# dtypes: float64(4), int32(1)
# memory usage: 5.4 KB

# %%
_ = df_iris.hist(bins=50)

# %% [markdown]
# #### 결측치

# %%
df_iris.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# label                0
# dtype: int64

# %% [markdown]
# `sklearn`에서 제공하는 `iris` 데이터에서, 결측치는 존재하지 않음

# %% [markdown]
# ### 분포

# %%
_ = sns.scatterplot(data=df_iris, x="sepal length (cm)", y="sepal width (cm)", hue="label").set_title("Scatter - sepal")

# %%
_ = sns.scatterplot(data=df_iris, x="petal length (cm)", y="petal width (cm)", hue="label").set_title("Scatter - petal")

# %% [markdown]
# 꽃잎(petal)의 데이터는 꽃받침(sepal)에 비해 비교적 잘 뭉쳐있는 모습을 확인 가능함
#
# 해당 데이터 셋은 따로 전처리를 할 필요가 없을것 같음
